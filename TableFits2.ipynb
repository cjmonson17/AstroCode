# %%
from astropy.io import fits
import numpy as np #imports numpy
import matplotlib.pyplot as plt
import seaborn as sns # provides a high-level interface to draw statitistical graphics
from pylab import *
# %config InlineBackend.figure_format = 'retina' #makes images clearer
# %matplotlib inline 
#^put plots in line?

# %%
var = fits.open("../Desktop/CJ_Astro/WAVE_PHOENIX-ACES-AGSS-COND-2011 (2).fits")
wave = var[0].data

# %% [markdown]
# # PHOENIX FILE 1 > 05400-3.50-0.0.

# %%
#fits_table_filename = fits.util.get_testdata_filepath('btable.fits')

hdu1 = fits.open("../Desktop/CJ_Astro/lte02300-3.50-0.0.PHOENIX-ACES-AGSS-COND-2011-HiRes.fits")  # open a FITS file
hdu2 = fits.open("../Desktop/CJ_Astro/lte09000-3.50-0.0.PHOENIX-ACES-AGSS-COND-2011-HiRes.fits")
hdu3 = fits.open("../Desktop/CJ_Astro/lte05000-3.50-0.0.PHOENIX-ACES-AGSS-COND-2011-HiRes.fits")
hdu3a = fits.open("../Desktop/CJ_Astro/lte05000-4.00-0.0.PHOENIX-ACES-AGSS-COND-2011-HiRes.fits")
hdu4 = fits.open("../Desktop/CJ_Astro/lte06000-3.50-0.0.PHOENIX-ACES-AGSS-COND-2011-HiRes.fits")
hdu1.info()
data = hdu1[1].data  # assume the first extension is a table
mu = hdu1[0].data
mu2 = hdu2[0].data
mu3 = hdu3[0].data
mu3a = hdu3a[0].data
mu4 = hdu4[0].data


# show the first two rows
first_two_rows1 = data[:2]
#print(first_two_rows1)
# show the values in field "mag"

# columns can be referenced by index too
#elements1 = data.field(1)
#temp1 = data.field(0)
#flux1 = data.field(2)


hdu1.close()
# Out:
# Filename: ../Desktop/CJ_Astro/lte02300-3.50-0.0.PHOENIX-ACES-AGSS-COND-2011-HiRes.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   (1569128,)   float32
#   1  ABUNDANCES    1 BinTableHDU     15   83R x 3C   [I, 2A, E]

# %%
plt.plot(wave, mu, color = 'steelblue')

#plt.plot(temp2, flux2, color = 'red')
plt.xlabel("Temperature K")
plt.ylabel("Flux")
plt.title("lte02300-3.50-0.0.PHOENIX")
plt.show()

# %%
plt.plot(wave, mu2, color = 'firebrick')
plt.xlabel("Temperature K")
plt.ylabel("Flux")
plt.title("lte09000-3.50-0.0.PHOENIX")
plt.show()

# %%
plt.plot(wave, mu3, color = 'darkorange')
plt.plot(wave+10000, mu3a, color = 'limegreen')
#plt.plot(wave, mu4, color = 'blue')
plt.xlabel("Temperature K")
plt.ylabel("Flux")
plt.title("lte05000-3.50-0.0.PHOENIX")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-33671759b495> in <module>()
#       6 plt.title("lte05000-3.50-0.0.PHOENIX")
#       7 plt.show()
# ----> 8 print(wave(5000))
#       9 print(mu3a.max)
#
# TypeError: 'numpy.ndarray' object is not callable
